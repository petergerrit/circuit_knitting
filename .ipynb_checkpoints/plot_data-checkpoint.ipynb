# %%
import import_ipynb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pickle
from datetime import datetime
from collections import defaultdict

from functions import *
from params import *

# %%
shots_list = [1024*i**2 for i in range(11)]

# %%
with open('data/ferm_num_step1_epsilon08_with_noise_no_knit.txt', 'w') as file:
    for item in ferm_num_step1_epsilon08_with_noise_no_knit:
        file.write("%s\n" % item)

with open('data/bs_error_step1_epsilon08_with_noise_no_knit.txt', 'w') as file:
    for item in bs_error_step1_epsilon08_with_noise_no_knit:
        file.write("%s\n" % item)

# %%
with open('data/ferm_num_step1_epsilon08_no_noise_knitted.txt', 'w') as file:
    for item in ferm_num_step1_epsilon08_no_noise_knitted:
        file.write("%s\n" % item)

with open('data/bs_error_step1_epsilon08_no_noise_knitted.txt', 'w') as file:
    for item in bs_error_step1_epsilon08_no_noise_knitted:
        file.write("%s\n" % item)

# %%
ferm_num_step1_epsilon08_with_noise_knitted = []
bs_error_step1_epsilon08_with_noise_knitted = []
for i in range(11):
    with open('data/step1_epsilon08_count' + str(1024*2**i) + '_with_noise_knitted.pkl', 'rb') as file:
        counts = pickle.load(file)
    ferm_num_step1_epsilon08_with_noise_knitted.append(fermion_number(counts, mid))
    bs_error_step1_epsilon08_with_noise_knitted.append(bootstrap_error(counts, mid, 1024*2**i))

# %%
with open('data/ferm_num_step1_epsilon08_with_noise_knitted.txt', 'w') as file:
    for item in ferm_num_step1_epsilon08_with_noise_knitted:
        file.write("%s\n" % item)

with open('data/bs_error_step1_epsilon08_with_noise_knitted.txt', 'w') as file:
    for item in bs_error_step1_epsilon08_with_noise_knitted:
        file.write("%s\n" % item)

# %%
ferm_num_step2_epsilon08_no_noise_no_knit = []
bs_error_step2_epsilon08_no_noise_no_knit = []
for i in range(11):
    num_shots = 1024*2**i
    res = do_run(trot_step_2, num_shots)
    ferm_num_step2_epsilon08_no_noise_no_knit.append(fermion_number(res, mid))
    bs_error_step2_epsilon08_no_noise_no_knit.append(bootstrap_error(res, mid, num_shots))

# %%
with open('data/ferm_num_step2_epsilon08_no_noise_no_knit.txt', 'w') as file:
    for item in ferm_num_step2_epsilon08_no_noise_no_knit:
        file.write("%s\n" % item)

with open('data/bs_error_step2_epsilon08_no_noise_no_knit.txt', 'w') as file:
    for item in bs_error_step2_epsilon08_no_noise_no_knit:
        file.write("%s\n" % item)

# %%
ferm_num_step2_epsilon08_with_noise_no_knit = []
bs_error_step2_epsilon08_with_noise_no_knit = []
for i in range(11):
    num_shots = 1024*2**i
    res = do_run(trot_step_2, num_shots, noise=True)
    ferm_num_step2_epsilon08_with_noise_no_knit.append(fermion_number(res, mid))
    bs_error_step2_epsilon08_with_noise_no_knit.append(bootstrap_error(res, mid, num_shots))

# %%
with open('data/ferm_num_step2_epsilon08_with_noise_no_knit.txt', 'w') as file:
    for item in ferm_num_step2_epsilon08_with_noise_no_knit:
        file.write("%s\n" % item)

with open('data/bs_error_step2_epsilon08_with_noise_no_knit.txt', 'w') as file:
    for item in bs_error_step2_epsilon08_with_noise_no_knit:
        file.write("%s\n" % item)

# %%
ferm_num_step2_epsilon08_no_noise_knitted = []
bs_error_step2_epsilon08_no_noise_knitted = []
for i in range(11):
    with open('data/step2_epsilon08_count' + str(1024*2**i) + '_no_noise_knitted.pkl', 'rb') as file:
        counts = pickle.load(file)
    ferm_num_step2_epsilon08_no_noise_knitted.append(fermion_number(counts, mid))
    bs_error_step2_epsilon08_no_noise_knitted.append(bootstrap_error(counts, mid, 1024*2**i))

# %%
with open('data/ferm_num_step2_epsilon08_no_noise_knitted.txt', 'w') as file:
    for item in ferm_num_step2_epsilon08_no_noise_knitted:
        file.write("%s\n" % item)

with open('data/bs_error_step2_epsilon08_no_noise_knitted.txt', 'w') as file:
    for item in bs_error_step2_epsilon08_no_noise_knitted:
        file.write("%s\n" % item)

# %% [markdown]
# # Exact Trotter evolution

# %%
epsilon = 0.05
ferm_num_exact_no_noise_no_knit = []
bs_error_exact_no_noise_no_knit = []
trotter_steps = []
for i in range(32):
    step = int(4*(i+1))
    num_shots = 1024**2
    circuit = trotter_stepper(step, Nqbits, epsilon, mass, mid).decompose().decompose()
    circuit.measure_all()
    res = do_run(circuit, num_shots)
    ferm_num_exact_no_noise_no_knit.append(fermion_number(res, mid))
    bs_error_exact_no_noise_no_knit.append(bootstrap_error(res, mid, num_shots))
    trotter_steps.append(step*epsilon)

# %%
ferm_num_exact_no_noise_no_knit = np.array(ferm_num_exact_no_noise_no_knit)
bs_error_exact_no_noise_no_knit = np.array(bs_error_exact_no_noise_no_knit)
trotter_steps = np.array(trotter_steps)

# %%
np.save('data/ferm_num_exact_no_noise_no_knit', ferm_num_exact_no_noise_no_knit)
np.save('data/bs_error_exact_no_noise_no_knit', bs_error_exact_no_noise_no_knit)
np.save('data/trotter_steps', trotter_steps)

# %%
epsilon = 0.01
ferm_num_exact_no_noise_no_knit_epsilon001 = []
bs_error_exact_no_noise_no_knit001 = []
trotter_steps = []
for i in range(32):
    step = int(20*(i+1))
    num_shots = 1024**2
    circuit = trotter_stepper(step, Nqbits, epsilon, mass, mid).decompose().decompose()
    circuit.measure_all()
    res = do_run(circuit, num_shots)
    ferm_num_exact_no_noise_no_knit_epsilon001.append(fermion_number(res, mid))
    bs_error_exact_no_noise_no_knit001.append(bootstrap_error(res, mid, num_shots))
    trotter_steps.append(step*epsilon)

# %%
with open('data/ferm_num_exact_no_noise_no_knit_epsilon001.txt', 'w') as file:
    for item in ferm_num_exact_no_noise_no_knit_epsilon001:
        file.write("%s\n" % item)

with open('data/bs_error_exact_no_noise_no_knit001.txt', 'w') as file:
    for item in bs_error_exact_no_noise_no_knit001:
        file.write("%s\n" % item)

# %%
ferm_num_trotter_evol_no_noise_no_knit = []
bs_error_trotter_evol_no_noise_no_knit = []
for i in range(8):
    shots=1024**2
    if i < 4:
        step = 1
        #shots = 131072
        eps = 0.2*(i+1)
    else:
        step = 2
        #shots = 65536
        eps = 0.1*(i+1)
    circuit = trotter_stepper(step, Nqbits, eps, mass, mid).decompose().decompose()
    circuit.measure_all()
    res = do_run(circuit, shots)
    ferm_num_trotter_evol_no_noise_no_knit.append(fermion_number(res, mid))
    bs_error_trotter_evol_no_noise_no_knit.append(bootstrap_error(res, mid, shots))

# %%
with open('data/ferm_num_trotter_evol_no_noise_no_knit.txt', 'w') as file:
    for item in ferm_num_trotter_evol_no_noise_no_knit:
        file.write("%s\n" % item)

with open('data/bs_error_trotter_evol_no_noise_no_knit.txt', 'w') as file:
    for item in bs_error_trotter_evol_no_noise_no_knit:
        file.write("%s\n" % item)

# %% [markdown]
# # noisy, no knit Trotter evolution

# %% [markdown]
# ## do runs

# %%
def make_runs(my_seed=None, shots=8192):
    if not my_seed:
        my_seed = int(datetime.now().timestamp())
    ferm_num_trotter_evol_noisy_no_knit = np.empty(0)
    bs_error_trotter_evol_noisy_no_knit = np.empty(0)
    for i in range(8):
        np.random.seed(my_seed)
        if i < 4:
            step = 1
            eps = np.round(0.2*(i+1), 1)
        else:
            step = 2
            eps = np.round(0.1*(i+1), 1)
        circuit = trotter_stepper(step, Nqbits, eps, mass, mid).decompose().decompose()
        circuit.measure_all()
        res = do_run(circuit, shots, noise=True, simulator_seed=np.random.randint(1024**2), transpiler_seed=np.random.randint(1024**2))
        ferm_num_trotter_evol_noisy_no_knit = np.append(ferm_num_trotter_evol_noisy_no_knit, fermion_number(res, mid))
        bs_error_trotter_evol_noisy_no_knit = np.append(bs_error_trotter_evol_noisy_no_knit, bootstrap_error(res, mid, shots))
    return {my_seed: {'fermion_number': ferm_num_trotter_evol_noisy_no_knit, 'bootstrap_error': bs_error_trotter_evol_noisy_no_knit}}

# %%
noisy_no_knitt_trotter_evolution=defaultdict(dict)
for i in range(10):
    print(i)
    noisy_no_knitt_trotter_evolution = noisy_no_knitt_trotter_evolution | make_runs()

# %%
with open('data/noisy_no_knitt_trotter_evolution.pkl', 'wb') as file:
         pickle.dump(noisy_no_knitt_trotter_evolution, file, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## resample

# %%
with open('data/noisy_no_knitt_trotter_evolution.pkl', 'rb') as file:
    noisy_no_knitt_trotter_evolution = pickle.load(file)

# %%
no_knit_noisy_resampled_fermion_number = np.empty(0)
no_knit_noisy_resampled_bootstrap_error = np.empty(0)
for i in range(8):
    running_resampling = np.empty(0)
    for item in noisy_no_knitt_trotter_evolution:
        full_res = noisy_no_knitt_trotter_evolution[item]
        ferm_num = full_res['fermion_number'][i]
        bs_error = full_res['bootstrap_error'][i]
        running_resampling = np.append(running_resampling, np.random.normal(ferm_num, bs_error, 1000))
    no_knit_noisy_resampled_fermion_number = np.append(no_knit_noisy_resampled_fermion_number, running_resampling.mean())
    no_knit_noisy_resampled_bootstrap_error = np.append(no_knit_noisy_resampled_bootstrap_error, running_resampling.std())

# %%
np.save('data/no_knit_noisy_resampled_fermion_number', no_knit_noisy_resampled_fermion_number)
np.save('data/no_knit_noisy_resampled_bootstrap_error', no_knit_noisy_resampled_bootstrap_error)

# %%
ferm_num_trotter_evol_noisy_no_knit = []
bs_error_trotter_evol_noisy_no_knit = []
for i in range(8):
    print(i)
    shots = 1024**2
    if i < 4:
        step = 1
        #shots = 131072
        eps = np.round(0.2*(i+1), 1)
    else:
        step = 2
        #shots = 65536
        eps = np.round(0.1*(i+1), 1)
    circuit = trotter_stepper(step, Nqbits, eps, mass, mid).decompose().decompose()
    circuit.measure_all()
    res = do_run(circuit, shots, noise=True, simulator_seed=i+100, transpiler_seed=i+108)
    ferm_num_tro8ter_evol_noisy_no_knit.append(fermion_number(res, mid))
    bs_error_trotter_evol_noisy_no_knit.append(bootstrap_error(res, mid, shots))

# %%
with open('data/ferm_num_trotter_evol_noisy_no_knit.txt', 'w') as file:
    for item in ferm_num_trotter_evol_noisy_no_knit:
        file.write("%s\n" % item)

with open('data/bs_error_trotter_evol_noisy_no_knit.txt', 'w') as file:
    for item in bs_error_trotter_evol_noisy_no_knit:
        file.write("%s\n" % item)

# %% [markdown]
# # noisy, knitted Trotter evolution

# %%
noisy_knitted_seeds_list = []
with open('data/noisy_knitted_trotter_evol/noisy_knitted_seeds_list.txt', 'r') as file:
    for line in file:
        val = line[:-1]
        noisy_knitted_seeds_list.append(int(val))
seed=noisy_knitted_seeds_list[0]
other_seed = noisy_knitted_seeds_list[-1]

# %%
np.round(0.6000000000000001, 1)

# %%
step=1
ferm_num_orig = []
ferm_num_upd = []
ferm_num_other = []
dif_list = []
check_list = []
for i in range(4):
    eps = np.round(0.2*(i+1), 1)
    with open('data/noisy_knitted_trotter_evol/step'+str(step)+\
                      '_epsilon0'+str(eps)[-1]+'_count16384_with_noise_knitted_seed'+str(seed)+'.pkl', 'rb') as file:
        ferm_num_orig.append(fermion_number(pickle.load(file), mid))
    with open('data/noisy_knitted_trotter_evol/TEST_step'+str(step)+\
                      '_epsilon0'+str(eps)[-1]+'_count16384_with_noise_knitted_seed'+str(seed)+'.pkl', 'rb') as file:
        ferm_num_upd.append(fermion_number(pickle.load(file), mid))
    with open('data/noisy_knitted_trotter_evol/step'+str(step)+\
                      '_epsilon0'+str(eps)[-1]+'_count16384_with_noise_knitted_seed'+str(other_seed)+'.pkl', 'rb') as file:
        ferm_num_other.append(fermion_number(pickle.load(file), mid))
    dif_list.append(ferm_num_orig[i]-ferm_num_upd[i])
    check_list.append(ferm_num_orig[i]-ferm_num_other[i])

# %%
dif_list

# %%
check_list

# %% [markdown]
# ## process data

# %%
seeds_noisy_knitted_trotter = []
with open('data/noisy_knitted_trotter_evol/noisy_knitted_seeds_list.txt', 'r') as file:
    for line in file:
        val = line[:-1]
        seeds_noisy_knitted_trotter.append(float(val))
seeds_noisy_knitted_trotter = list(set([int(item) for item in seeds_noisy_knitted_trotter]))

# %%
noisy_knitted_trotter_evolution=defaultdict(dict)
for seed in seeds_noisy_knitted_trotter:
    ferm_nums = np.empty(0)
    bootstrap = np.empty(0)
    for i in range(8):
        if i < 4:
            step = 1
            eps = np.round(0.2*(i+1), 1)
        else:
            step = 2
            eps = np.round(0.1*(i+1), 1)
        with open('data/noisy_knitted_trotter_evol/step'+str(step)+\
                  '_epsilon0'+str(eps)[-1]+'_count16384_with_noise_knitted_seed'+str(seed)+'.pkl', 'rb') as file:
            res = pickle.load(file)
        ferm_nums = np.append(ferm_nums, fermion_number(res, mid))
        bootstrap = np.append(bootstrap, bootstrap_error(res, mid, 16384))
    noisy_knitted_trotter_evolution = noisy_knitted_trotter_evolution | {seed : {'fermion_number': ferm_nums, 'bootstrap_error': bootstrap}}

# %%
with open('data/noisy_knitted_trotter_evolution.pkl', 'wb') as file:
         pickle.dump(noisy_knitted_trotter_evolution, file, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## resample

# %%
with open('data/noisy_knitted_trotter_evolution.pkl', 'rb') as file:
    noisy_knitted_trotter_evolution = pickle.load(file)

# %%
knitted_noisy_resampled_fermion_number = np.empty(0)
knitted_noisy_resampled_bootstrap_error = np.empty(0)
for i in range(8):
    running_resampling = np.empty(0)
    for item in seeds_noisy_knitted_trotter:
        full_res = noisy_knitted_trotter_evolution[item]
        ferm_num = full_res['fermion_number'][i]
        bs_error = full_res['bootstrap_error'][i]
        running_resampling = np.append(running_resampling, np.random.normal(ferm_num, bs_error, 1000))
    knitted_noisy_resampled_fermion_number = np.append(knitted_noisy_resampled_fermion_number, running_resampling.mean())
    knitted_noisy_resampled_bootstrap_error = np.append(knitted_noisy_resampled_bootstrap_error, running_resampling.std())

# %%
np.save('data/knitted_noisy_resampled_fermion_number', knitted_noisy_resampled_fermion_number)
np.save('data/knitted_noisy_resampled_bootstrap_error', knitted_noisy_resampled_bootstrap_error)

# %%
ferm_num_trotter_evol_noisy_knit = []
bs_error_trotter_evol_noisy_knit = []
for i in range(8):
    if i < 4:
        step = 1
        shots = 131072
        eps = 0.2*(i+1)
    else:
        step = 2
        shots = 65536
        eps = 0.1*(i+1)
    with open('data/step'+str(step)+'_epsilon0'+str(eps)[2]+'_count'+str(shots)+'_with_noise_knitted.pkl', 'rb') as file:
        counts = pickle.load(file)
    ferm_num_trotter_evol_noisy_knit.append(fermion_number(counts, mid))
    bs_error_trotter_evol_noisy_knit.append(bootstrap_error(counts, mid, shots))

# %%
with open('data/ferm_num_trotter_evol_noisy_knit.txt', 'w') as file:
    for item in ferm_num_trotter_evol_noisy_knit:
        file.write("%s\n" % item)

with open('data/bs_error_trotter_evol_noisy_knit.txt', 'w') as file:
    for item in bs_error_trotter_evol_noisy_knit:
        file.write("%s\n" % item)

# %%
# just do first step for everything
ferm_num_trotter_evol_noisy_knit_step1 = []
bs_error_trotter_evol_noisy_knit_step1 = []
for i in range(8):
    step = 1
    shots = 131072
    eps = 0.2*(i+1)
    with open('data/step'+str(step)+'_epsilon'+str(eps)[0]+str(eps)[2]+'_count'+str(shots)+'_with_noise_knitted.pkl', 'rb') as file:
        counts = pickle.load(file)
    ferm_num_trotter_evol_noisy_knit_step1.append(fermion_number(counts, mid))
    bs_error_trotter_evol_noisy_knit_step1.append(bootstrap_error(counts, mid, shots))

# %%
with open('data/ferm_num_trotter_evol_noisy_knit_step1.txt', 'w') as file:
    for item in ferm_num_trotter_evol_noisy_knit_step1:
        file.write("%s\n" % item)

with open('data/bs_error_trotter_evol_noisy_knit_step1.txt', 'w') as file:
    for item in bs_error_trotter_evol_noisy_knit_step1:
        file.write("%s\n" % item)

# %%
## multiple runs
