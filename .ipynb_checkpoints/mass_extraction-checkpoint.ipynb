# %%
import import_ipynb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

import pickle
from datetime import datetime
from collections import defaultdict
from functools import reduce

from functions_coupling_to_0 import *
from params import *

# %%
def fit_func(x, A, B):
    return np.cos(A*x)*np.exp(B*x)

# %%
def make_plot(data):
    my_data = np.genfromtxt(data, delimiter=',')
    time_pts, fnum_pts = my_data[:,0], my_data[:,1]
    params, _ = curve_fit(fit_func, time_pts, fnum_pts)
    plt.scatter(time_pts, fnum_pts)
    plt.plot(np.linspace(time_pts[0], time_pts[-1], 100), [fit_func(i, *params) for i in np.linspace(time_pts[0], time_pts[-1], 100)])

# %%
def get_mass(data):
    my_data = np.genfromtxt(data, delimiter=',')
    time_pts, fnum_pts = my_data[:,0], my_data[:,1]
    params, _ = curve_fit(fit_func, time_pts, fnum_pts)
    return params[0]

# %%
def get_fit(data):
    my_data = np.genfromtxt(data, delimiter=',')
    time_pts, fnum_pts = my_data[:,0], my_data[:,1]
    params, _ = curve_fit(fit_func, time_pts, fnum_pts)
    return params

# %%
get_mass('digitized_data_N2_m1.csv')
# Out:
# np.float64(0.9130351239893183)

# %%
make_plot('digitized_data_N2_m1.csv')

# %%
get_mass('digitized_data_N4_m1.csv')
# Out:
# np.float64(0.9910544835027808)

# %%
make_plot('digitized_data_N4_m1.csv')

# %%
make_plot('digitized_data_N2_m2.csv')

# %%
get_mass('digitized_data_N2_m2.csv')
# Out:
# np.float64(1.5040842631490017)

# %%
make_plot('digitized_data_N4_m2.csv')

# %%
get_mass('digitized_data_N4_m2.csv')
# Out:
# np.float64(1.548892171493846)

# %%
func = np.genfromtxt('digitized_data_N2_m1.csv', delimiter=',')[:,1]
time = np.genfromtxt('digitized_data_N2_m1.csv', delimiter=',')[:,0]
reduce(lambda x, y: x+y, [func[i]*np.cos(0.9*time[i]) for i in range(len(time))], 0)
# Out:
# np.float64(8.61758392153915)

# %%
def dft(omega):
    func = np.genfromtxt('digitized_data_N2_m1.csv', delimiter=',')[:,1]
    time = np.genfromtxt('digitized_data_N2_m1.csv', delimiter=',')[:,0]
    return reduce(lambda x, y: x+y, [func[i]*np.cos(omega*time[i]) for i in range(len(time))], 0)

# %%
def dft(omega, time, val):
    return reduce(lambda x, y: x+y, [val[i]*np.cos(omega*time[i]) for i in range(len(time))], 0)

# %%
np.genfromtxt('digitized_data_N2_m1.csv', delimiter=',')[:,0]
# Out:
# array([ 1.01669196,  1.99544765,  2.9969651 ,  4.04400607,  5.        ,
#         7.0030349 ,  7.98179059, 10.00758725, 11.0091047 , 11.98786039,
#        12.98937785, 13.9908953 , 14.99241275, 15.9939302 , 17.01820941,
#        17.9969651 , 18.97572079, 20.        ])

# %%
get_fit('digitized_data_N2_m1.csv')
# Out:
# array([ 0.91303512, -0.00271234])

# %%
np.linspace(1.01669196, 20., 100)
# Out:
# array([ 1.01669196,  1.20844255,  1.40019313,  1.59194372,  1.78369431,
#         1.97544489,  2.16719548,  2.35894606,  2.55069665,  2.74244724,
#         2.93419782,  3.12594841,  3.317699  ,  3.50944958,  3.70120017,
#         3.89295075,  4.08470134,  4.27645193,  4.46820251,  4.6599531 ,
#         4.85170369,  5.04345427,  5.23520486,  5.42695544,  5.61870603,
#         5.81045662,  6.0022072 ,  6.19395779,  6.38570838,  6.57745896,
#         6.76920955,  6.96096013,  7.15271072,  7.34446131,  7.53621189,
#         7.72796248,  7.91971307,  8.11146365,  8.30321424,  8.49496482,
#         8.68671541,  8.878466  ,  9.07021658,  9.26196717,  9.45371776,
#         9.64546834,  9.83721893, 10.02896951, 10.2207201 , 10.41247069,
#        10.60422127, 10.79597186, 10.98772245, 11.17947303, 11.37122362,
#        11.5629742 , 11.75472479, 11.94647538, 12.13822596, 12.32997655,
#        12.52172714, 12.71347772, 12.90522831, 13.09697889, 13.28872948,
#        13.48048007, 13.67223065, 13.86398124, 14.05573183, 14.24748241,
#        14.439233  , 14.63098358, 14.82273417, 15.01448476, 15.20623534,
#        15.39798593, 15.58973652, 15.7814871 , 15.97323769, 16.16498827,
#        16.35673886, 16.54848945, 16.74024003, 16.93199062, 17.12374121,
#        17.31549179, 17.50724238, 17.69899296, 17.89074355, 18.08249414,
#        18.27424472, 18.46599531, 18.6577459 , 18.84949648, 19.04124707,
#        19.23299765, 19.42474824, 19.61649883, 19.80824941, 20.        ])

# %%
[fit_func(i, 0.91303512, -0.00271234) for i in np.linspace(1.01669196, 20., 100)]
# Out:
# [np.float64(0.597565384703397),
#  np.float64(0.44913306208566744),
#  np.float64(0.28713070675439634),
#  np.float64(0.11652280145248167),
#  np.float64(-0.05746836893282481),
#  np.float64(-0.2295225649683236),
#  np.float64(-0.39438426732719467),
#  np.float64(-0.54702320463771),
#  np.float64(-0.682787831442648),
#  np.float64(-0.7975470737076386),
#  np.float64(-0.8878160226983666),
#  np.float64(-0.9508617530334698),
#  np.float64(-0.9847860520497795),
#  np.float64(-0.9885825564876061),
#  np.float64(-0.9621665771534271),
#  np.float64(-0.9063767285898984),
#  np.float64(-0.8229483432674531),
#  np.float64(-0.7144595120253858),
#  np.float64(-0.5842514280865508),
#  np.float64(-0.4363254954425696),
#  np.float64(-0.27522036986910603),
#  np.float64(-0.10587271074400437),
#  np.float64(0.06653408433090253),
#  np.float64(0.23672852733038008),
#  np.float64(0.399512214485461),
#  np.float64(0.5499186001320795),
#  np.float64(0.6833645205047749),
#  np.float64(0.7957898448360953),
#  np.float64(0.8837809987271502),
#  np.float64(0.9446746020003777),
#  np.float64(0.9766380748025341),
#  np.float64(0.9787247727878509),
#  np.float64(0.9509019930728755),
#  np.float64(0.8940510233779029),
#  np.float64(0.8099392619185214),
#  np.float64(0.7011652890280782),
#  np.float64(0.5710785971013945),
#  np.float64(0.42367645805226656),
#  np.float64(0.26348110351846565),
#  np.float64(0.09540099133862512),
#  np.float64(-0.07541958581525654),
#  np.float64(-0.24375794195679262),
#  np.float64(-0.4044726711187338),
#  np.float64(-0.5526606709748801),
#  np.float64(-0.6838067212677342),
#  np.float64(-0.7939210540507092),
#  np.float64(-0.8796607244368705),
#  np.float64(-0.938431089918472),
#  np.float64(-0.9684643179906345),
#  np.float64(-0.9688725469708201),
#  np.float64(-0.9396741019080327),
#  np.float64(-0.8817919925042274),
#  np.float64(-0.7970247677644389),
#  np.float64(-0.6879906467216343),
#  np.float64(-0.5580466602408365),
#  np.float64(-0.41118530070033116),
#  np.float64(-0.25191186105330754),
#  np.float64(-0.08510623154852304),
#  np.float64(0.08412660659530252),
#  np.float64(0.25061281028189236),
#  np.float64(0.40926784544871564),
#  np.float64(0.5552517644826385),
#  np.float64(0.6841168482703213),
#  np.float64(0.7919431092605653),
#  np.float64(0.8754575275342957),
#  np.float64(0.9321333932468621),
#  np.float64(0.9602667404757929),
#  np.float64(0.9590275606692827),
#  np.float64(0.9284842569645776),
#  np.float64(0.8696006199352682),
#  np.float64(0.7842054457488217),
#  np.float64(0.6749357535673631),
#  np.float64(0.5451553647691278),
#  np.float64(0.3988513576148044),
#  np.float64(0.2405115844391522),
#  np.float64(0.07498701381532002),
#  np.float64(-0.0926568800626071),
#  np.float64(-0.25729512823410067),
#  np.float64(-0.41389993467730446),
#  np.float64(-0.5576942117806442),
#  np.float64(-0.6842972951887981),
#  np.float64(-0.7898583934832908),
#  np.float64(-0.8711737075706153),
#  np.float64(-0.925783657888715),
#  np.float64(-0.952047269099617),
#  np.float64(-0.949191463011718),
#  np.float64(-0.9173337795534646),
#  np.float64(-0.857477859129412),
#  np.float64(-0.7714818527246871),
#  np.float64(-0.6620007532092482),
#  np.float64(-0.5324044371614226),
#  np.float64(-0.3866739468939357),
#  np.float64(-0.22927920465906237),
#  np.float64(-0.0650419150757624),
#  np.float64(0.1010121394735094),
#  np.float64(0.2638068859764955),
#  np.float64(0.4183711247929745),
#  np.float64(0.5599903276810011),
#  np.float64(0.6843504347902691),
#  np.float64(0.787669264875086)]

# %%
plt.plot(np.linspace(0, 2, 100), [dft_alt(i, np.linspace(1.01669196, 20., 100), [fit_func(i, 0.91303512, -0.00271234) for i in np.linspace(1.01669196, 20., 100)]) for i in np.linspace(0, 2, 100)])

# %%
plt.plot(np.linspace(0, 2.5, 1000), [dft(i) for i in np.linspace(0, 2.5, 1000)])

# %%
my_data = np.genfromtxt('digitized_data_N2_m1.csv', delimiter=',')

# %%
time_pts = my_data[:,0]

# %%
fnum_pts = my_data[:,1]

# %%
params, _ = curve_fit(fit_func, time_pts, fnum_pts)

# %%
params
# Out:
# array([ 0.91303512, -0.00271234])

# %%
np.linspace(time_pts[0], time_pts[-1], 100)
# Out:
# array([ 1.01669196,  1.20844254,  1.40019313,  1.59194372,  1.7836943 ,
#         1.97544489,  2.16719548,  2.35894606,  2.55069665,  2.74244723,
#         2.93419782,  3.12594841,  3.31769899,  3.50944958,  3.70120017,
#         3.89295075,  4.08470134,  4.27645192,  4.46820251,  4.6599531 ,
#         4.85170368,  5.04345427,  5.23520486,  5.42695544,  5.61870603,
#         5.81045661,  6.0022072 ,  6.19395779,  6.38570837,  6.57745896,
#         6.76920955,  6.96096013,  7.15271072,  7.34446131,  7.53621189,
#         7.72796248,  7.91971306,  8.11146365,  8.30321424,  8.49496482,
#         8.68671541,  8.878466  ,  9.07021658,  9.26196717,  9.45371775,
#         9.64546834,  9.83721893, 10.02896951, 10.2207201 , 10.41247069,
#        10.60422127, 10.79597186, 10.98772244, 11.17947303, 11.37122362,
#        11.5629742 , 11.75472479, 11.94647538, 12.13822596, 12.32997655,
#        12.52172713, 12.71347772, 12.90522831, 13.09697889, 13.28872948,
#        13.48048007, 13.67223065, 13.86398124, 14.05573183, 14.24748241,
#        14.439233  , 14.63098358, 14.82273417, 15.01448476, 15.20623534,
#        15.39798593, 15.58973652, 15.7814871 , 15.97323769, 16.16498827,
#        16.35673886, 16.54848945, 16.74024003, 16.93199062, 17.12374121,
#        17.31549179, 17.50724238, 17.69899296, 17.89074355, 18.08249414,
#        18.27424472, 18.46599531, 18.6577459 , 18.84949648, 19.04124707,
#        19.23299765, 19.42474824, 19.61649883, 19.80824941, 20.        ])

# %%
plt.scatter(time_pts, fnum_pts)
plt.plot(np.linspace(time_pts[0], time_pts[-1], 100), [fit_func(i, *params) for i in np.linspace(time_pts[0], time_pts[-1], 100)])

# %%
my_data
# Out:
# array([[ 1.01669196e+00,  6.07142857e-01],
#        [ 1.99544765e+00, -2.55952381e-01],
#        [ 2.99696510e+00, -8.86904762e-01],
#        [ 4.04400607e+00, -8.33333333e-01],
#        [ 5.00000000e+00, -9.52380952e-02],
#        [ 7.00303490e+00,  9.88095238e-01],
#        [ 7.98179059e+00,  5.29761905e-01],
#        [ 1.00075873e+01, -8.75000000e-01],
#        [ 1.10091047e+01, -7.67857143e-01],
#        [ 1.19878604e+01,  5.95238095e-03],
#        [ 1.29893778e+01,  7.55952381e-01],
#        [ 1.39908953e+01,  9.70238095e-01],
#        [ 1.49924127e+01,  4.58333333e-01],
#        [ 1.59939302e+01, -3.92857143e-01],
#        [ 1.70182094e+01, -9.16666667e-01],
#        [ 1.79969651e+01, -7.02380952e-01],
#        [ 1.89757208e+01,  2.38095238e-02],
#        [ 2.00000000e+01,  8.33333333e-01]])

# %%
epsilon = 0.05

# %%
def do_mass_scan(num):
    mass = num
    ferm_num_exact_no_noise_no_knit = np.zeros(0)
    bs_error_exact_no_noise_no_knit = np.zeros(0)
    for i in range(32):
        #print(i)
        step = int(4*(i+1))
        num_shots = 1024*32
        circuit = trotter_stepper(step, Nqbits, epsilon, mass, mid).decompose().decompose()
        circuit.measure_all()
        res = do_run(circuit, num_shots)
        ferm_num_exact_no_noise_no_knit=np.append(ferm_num_exact_no_noise_no_knit, fermion_number(res, mid))
        bs_error_exact_no_noise_no_knit=np.append(bs_error_exact_no_noise_no_knit,bootstrap_error(res, mid, num_shots))
    return ferm_num_exact_no_noise_no_knit, bs_error_exact_no_noise_no_knit

# %%
thing1, thing2 = do_mass_scan(9/8)

# %%
points10, err10 = do_mass_scan(10/8)

# %%
points11, err11 = do_mass_scan(11/8)

# %%
points12, err12 = do_mass_scan(12/8)

# %%
points13, err13 = do_mass_scan(13/8)

# %%
points14, err14 = do_mass_scan(14/8)

# %%
points15, err15 = do_mass_scan(15/8)

# %%
points16, err16 = do_mass_scan(16/8)

# %%
points17, err17 = do_mass_scan(17/8)

# %%
points18, err18 = do_mass_scan(18/8)

# %%
points19, err19 = do_mass_scan(19/8)

# %%
len(np.linspace(0, 6.4, 33))
# Out:
# 33

# %%
len(thing1)
# Out:
# 32

# %%
plt.scatter(np.linspace(0.2, 6.4, 32), thing1, color='red')
plt.scatter(np.linspace(0.2, 6.4, 32), points10, color='orange')
plt.scatter(np.linspace(0.2, 6.4, 32), points11, color='yellow')
plt.scatter(np.linspace(0.2, 6.4, 32), points12, color='green')
plt.scatter(np.linspace(0.2, 6.4, 32), points13, color='blue')
plt.scatter(np.linspace(0.2, 6.4, 32), points14, color='indigo')
plt.scatter(np.linspace(0.2, 6.4, 32), points15, color='violet')
plt.scatter(np.linspace(0.2, 6.4, 32), points16, color='black')
plt.scatter(np.linspace(0.2, 6.4, 32), points17, color='beige')
plt.scatter(np.linspace(0.2, 6.4, 32), points18, color='gold')
plt.scatter(np.linspace(0.2, 6.4, 32), points19, color='silver')
plt.show()

# %%
thing1
# Out:
# array([0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333])

# %%
points18
# Out:
# array([0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333, 0.50491333, 0.50491333, 0.50491333,
#        0.50491333, 0.50491333])

# %%
plt.scatter(np.linspace(0.2, 6.4, 32), thing1, color='red')
# plt.scatter(np.linspace(0.2, 6.4, 32), points10, color='orange')
# plt.scatter(np.linspace(0.2, 6.4, 32), points11, color='yellow')
# plt.scatter(np.linspace(0.2, 6.4, 32), points12, color='green')
# plt.scatter(np.linspace(0.2, 6.4, 32), points13, color='blue')
# plt.scatter(np.linspace(0.2, 6.4, 32), points14, color='indigo')
# plt.scatter(np.linspace(0.2, 6.4, 32), points15, color='violet')
# plt.scatter(np.linspace(0.2, 6.4, 32), points16, color='black')
# plt.scatter(np.linspace(0.2, 6.4, 32), points17, color='beige')
plt.scatter(np.linspace(0.2, 6.4, 32), points18, color='gold')
# plt.scatter(np.linspace(0.2, 6.4, 32), points19, color='silver')
plt.show()

# %%
fig, ax = plt.subplots()

plt.scatter(np.linspace(0, 2*np.pi, 100), [np.sin(i) for i in np.linspace(0, 2*np.pi, 100)])
plt.scatter(np.linspace(0, 2*np.pi, 100), [np.sin(np.pi*i/2) for i in np.linspace(0, 2*np.pi, 100)])

ratio = 1/2
x_left, x_right = ax.get_xlim()
y_low, y_high = ax.get_ylim()
ax.set_aspect(abs((x_right-x_left)/(y_low-y_high))*ratio)

# %%
def fit_func_alt(x, A, B, C, D, E, F, G, H, I):
    return A+(B*x)+(C*(x**2))+(D*(x**3)) + (E+(F*x)+(G*(x**2))+(H*(x**3)))*np.sin(I*x)

# %%
def exp_fit_func(x, A, B, C, D, E):
    return A*np.exp(-B*x) * np.cos(C*x) + D + E*x

# %%
ans_9, _ = curve_fit(exp_fit_func, np.linspace(0.2, 6.4, 32), thing1)

# %%
ans_18, _ = curve_fit(exp_fit_func, np.linspace(0.2, 6.4, 32), points18)#, p0=[ 0.48895098,  0.01047784, -0.00174909,  0.04318711, -0.02975097,
        # 0.00446448,  1.45416532])

# %%
ans_9
# Out:
# array([-0.01702091, -0.00704371,  1.87221653,  0.5209363 , -0.00412387])

# %%
ans_18
# Out:
# array([-7.60703206e-03, -9.36051585e-05, -2.89487122e+00,  5.11279977e-01,
#        -1.54868474e-03])

# %%
-1.54868474e-03 / -0.00412387
# Out:
# 0.37554160048692126

# %%
plt.scatter(np.linspace(0.2, 6.4, 32), thing1, color=(0, 114/256, 178/256))
plt.plot(np.linspace(0.2, 6.4, 32), [exp_fit_func(i, *ans_9) for i in np.linspace(0.2, 6.4, 32)], color=(0, 114/256, 178/256))
plt.scatter(np.linspace(0.2, 6.4, 32), points18, color=(213/256, 94/256, 0))
plt.plot(np.linspace(0.2, 6.4, 32), [exp_fit_func(i, *ans_18) for i in np.linspace(0.2, 6.4, 32)], color=(213/256, 94/256, 0))

# %%
1.83751421e+00/1.29449456e+00
# Out:
# 1.4194839181093197

# %%
ans_9 = [ 5.03099931e-01,  3.89940932e-03, -1.84110944e-04, -2.27081740e-03,
        2.52743422e-02, -4.91412030e-03,  1.29449456e+00]
ans_18 = [ 4.97497697e-01,  5.87929882e-03, -8.24478763e-05, -1.33824182e-04,
        6.28433018e-03,  1.65783595e-02, -9.57670250e-03,  1.09979136e-03,
        1.83751421e+00]

plt.scatter(np.linspace(0.2, 6.4, 32), thing1, color='red')
plt.plot(np.linspace(0.2, 6.4, 32), [fit_func(i, *ans_9) for i in np.linspace(0.2, 6.4, 32)], color='red')
plt.plot([4.853774980081481]*2, [0.49, 0.52], color='red')
plt.scatter(np.linspace(0.2, 6.4, 32), points18, color='gold')
plt.plot(np.linspace(0.2, 6.4, 32), [fit_func_alt(i, *ans_18) for i in np.linspace(0.2, 6.4, 32)], color='gold')
plt.plot([3.4193941320212082]*2, [0.49, 0.52], color='gold')
plt.show()

# %%
plt.scatter(np.linspace(0.2, 6.4, 32), points18, color='gold')
plt.plot(np.linspace(0.2, 6.4, 32), [fit_func(i,  0.48895073,  0.0104782 , -0.00174917,  0.04318717, -0.02975106,
        0.00446452,  1.45416045) for i in np.linspace(0.2, 6.4, 32)], color='gold')
plt.show()
